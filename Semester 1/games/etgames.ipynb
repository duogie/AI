# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_json('etgames.json')
sns.scatterplot(data=df, x='positive_ratio', y='discount')
# Out:
# <AxesSubplot:xlabel='positive_ratio', ylabel='discount'>
