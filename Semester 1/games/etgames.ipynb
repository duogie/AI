# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_json('etgames.json')
sns.scatterplot(data=df, x='price_original', y='price_final')
# Out:
# <AxesSubplot:xlabel='price_original', ylabel='price_final'>

# %%
df['price_original'].corr(df['price_final'])
# Out:
# 0.8882256789924982
