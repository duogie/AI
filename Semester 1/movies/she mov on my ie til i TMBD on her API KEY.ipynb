# %%
import pandas as pd
import seaborn as sns
import requests

# %% [markdown]
# # my api key 26c60ac04a3af348f5147e047c730b59

# %%
#the now playing endpoint
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmM2MGFjMDRhM2FmMzQ4ZjUxNDdlMDQ3YzczMGI1OSIsIm5iZiI6MTcyNzk3MDMzMC43NDUzNzksInN1YiI6IjY2ZmViNzQ1ZmEzZTY5ZTBlZjdjOTE4OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Sb4BKNjHednSV65-8KJsMw2yL3hvL0NCwBsBL9l2DxU"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response['results'])
now.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
# 1  False  /wh1IhMWkW7u5c5bkzSGFylF9G8r.jpg          [28, 80, 53]  1215162
# 2  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg             [878, 27]   933260
# 3  False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg           [10749, 18]  1079091
# 4  False  /A1dZ6faTjg0e6HYftBmEKujuXGQ.jpg          [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en                 The Crow
# 1                en           Kill 'em All 2
# 2                en            The Substance
# 3                en          It Ends with Us
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  Soulmates Eric and Shelly are brutally murdere...    1403.514
# 1  Phillip and Suzanne are retired from the spy g...    1201.354
# ...

# %%
#popular endpoint
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmM2MGFjMDRhM2FmMzQ4ZjUxNDdlMDQ3YzczMGI1OSIsIm5iZiI6MTcyNzk3MDMzMC43NDUzNzksInN1YiI6IjY2ZmViNzQ1ZmEzZTY5ZTBlZjdjOTE4OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Sb4BKNjHednSV65-8KJsMw2yL3hvL0NCwBsBL9l2DxU"
}

response = requests.get(url, headers=headers)

response = response.json()
popular = pd.DataFrame(response['results'])
popular.head()
# Out:
#    adult                     backdrop_path                genre_ids       id  \
# 0  False  /dvBCdCohwWbsP5qAaglOXagDMtk.jpg            [28, 35, 878]   533535
# 1  False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg      [16, 10751, 35, 28]   519182
# 2  False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg     [28, 14, 27, 53, 80]   957452
# 3  False  /p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg  [16, 10751, 12, 35, 18]  1022789
# 4  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg                [878, 27]   933260
#
#   original_language        original_title  \
# 0                en  Deadpool & Wolverine
# 1                en       Despicable Me 4
# 2                en              The Crow
# 3                en          Inside Out 2
# 4                en         The Substance
#
#                                             overview  popularity  \
# 0  A listless Wade Wilson toils away in civilian ...    6163.133
# 1  Gru and Lucy and their girls—Margo, Edith and ...    2244.623
# ...

# %%
#top rated endpoint
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmM2MGFjMDRhM2FmMzQ4ZjUxNDdlMDQ3YzczMGI1OSIsIm5iZiI6MTcyNzk3MDMzMC43NDUzNzksInN1YiI6IjY2ZmViNzQ1ZmEzZTY5ZTBlZjdjOTE4OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Sb4BKNjHednSV65-8KJsMw2yL3hvL0NCwBsBL9l2DxU"
}

response = requests.get(url, headers=headers)

response = response.json()
top = pd.DataFrame(response['results'])
top.head()
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg         [18, 80]  278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         [18, 80]  238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     136.210
# 1  Spanning the years 1945 to 1955, a chronicle o...     106.566
# 2  In the continuing saga of the Corleone crime f...      88.012
# ...

# %%
#upcoming endpoint
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmM2MGFjMDRhM2FmMzQ4ZjUxNDdlMDQ3YzczMGI1OSIsIm5iZiI6MTcyNzk3MDMzMC43NDUzNzksInN1YiI6IjY2ZmViNzQ1ZmEzZTY5ZTBlZjdjOTE4OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Sb4BKNjHednSV65-8KJsMw2yL3hvL0NCwBsBL9l2DxU"
}

response = requests.get(url, headers=headers)

response = response.json()
upcoming = pd.DataFrame(response['results'])
upcoming.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg             [878, 27]   933260
# 1  False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg          [18, 80, 53]   889737
# 2  False  /4zlOPT9CrtIX05bBIkYxNZsm5zN.jpg      [16, 878, 10751]  1184918
# 3  False  /tAwfoDyKiYa4KQdUp3DTMrEs4En.jpg  [16, 878, 12, 10751]   698687
# 4  False  /sjC29cgm4qZAnpOJQbYKCxDCcra.jpg         [27, 878, 53]  1062215
#
#   original_language       original_title  \
# 0                en        The Substance
# 1                en  Joker: Folie à Deux
# 2                en       The Wild Robot
# 3                en     Transformers One
# 4                en               Afraid
#
#                                             overview  popularity  \
# 0  A fading celebrity decides to use a black mark...    1131.940
# 1  While struggling with his dual identity, Arthu...     850.848
# 2  After a shipwreck, an intelligent robot called...     818.040
# ...

# %%
hawktuah=pd.concat(objs=[now, popular, top, upcoming], ignore_index=True)
hawk2 = hawktuah.drop_duplicates(subset=['title'])
hawk2
# Out:
#     adult                     backdrop_path             genre_ids       id  \
# 0   False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
# 1   False  /wh1IhMWkW7u5c5bkzSGFylF9G8r.jpg          [28, 80, 53]  1215162
# 2   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg             [878, 27]   933260
# 3   False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg           [10749, 18]  1079091
# 4   False  /A1dZ6faTjg0e6HYftBmEKujuXGQ.jpg          [35, 14, 27]   917496
# ..    ...                               ...                   ...      ...
# 75  False  /vJk9DOLgP23jO5mBnPHE93MFgYu.jpg   [12, 10751, 14, 35]   826510
# 76  False  /obKmfNexgL4ZP5cAmzdL4KbHHYX.jpg              [12, 14]      673
# 77  False  /AfXoko90cVuDz1KuVamkSMRKBWy.jpg              [35, 18]  1125073
# 78  False  /xlkclSE4aq7r3JsFIJRgs21zUew.jpg              [27, 53]  1034541
# 79  False  /b6DU3kBmicMbpNvvkqf1cHaceMF.jpg              [27, 18]   814889
#
#    original_language                            original_title  \
# ...

# %%
#top rated endpoint
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmM2MGFjMDRhM2FmMzQ4ZjUxNDdlMDQ3YzczMGI1OSIsIm5iZiI6MTcyNzk3MDMzMC43NDUzNzksInN1YiI6IjY2ZmViNzQ1ZmEzZTY5ZTBlZjdjOTE4OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Sb4BKNjHednSV65-8KJsMw2yL3hvL0NCwBsBL9l2DxU"
}

response = requests.get(url, headers=headers)

response = response.json()
top_rated = pd.DataFrame(response['results'])
top_rated.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 2  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 3  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 4  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
#
#   original_language            original_title  \
# 0                en            The Wild Robot
# 1                en  The Shawshank Redemption
# 2                en             The Godfather
# 3                en     The Godfather Part II
# 4                en          Schindler's List
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  Imprisoned in the 1940s for the double murder ...     248.751
# ...

# %%
df = pd.concat([now, popular, upcoming, top_rated])

# %%
df.drop_duplicates(subset=['id'], inplace=True)

# %%
def get_revenue_budget(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    Returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
money_df = get_revenue_budget(df)

# %%
money_df.head()
# Out:
#         id     budget    revenue
# 0   957452   50000000   13690814
# 1  1215162          0          0
# 2   933260   17500000   29106531
# 3  1079091   25000000  334836337
# 4   917496  100000000  434090643

# %%
df = pd.merge(df, money_df, how="inner", on="id")

# %%
df.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
# 1  False  /wh1IhMWkW7u5c5bkzSGFylF9G8r.jpg          [28, 80, 53]  1215162
# 2  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg             [878, 27]   933260
# 3  False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg           [10749, 18]  1079091
# 4  False  /A1dZ6faTjg0e6HYftBmEKujuXGQ.jpg          [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en                 The Crow
# 1                en           Kill 'em All 2
# 2                en            The Substance
# 3                en          It Ends with Us
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  Soulmates Eric and Shelly are brutally murdere...    1403.514
# 1  Phillip and Suzanne are retired from the spy g...    1201.354
# ...

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
import numpy as np
df["revenue_sqrt"] = np.sqrt(df["revenue"])
df["budget_sqrt"] = np.sqrt(df["budget"])

# %%
df.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
# 1  False  /wh1IhMWkW7u5c5bkzSGFylF9G8r.jpg          [28, 80, 53]  1215162
# 2  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg             [878, 27]   933260
# 3  False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg           [10749, 18]  1079091
# 4  False  /A1dZ6faTjg0e6HYftBmEKujuXGQ.jpg          [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en                 The Crow
# 1                en           Kill 'em All 2
# 2                en            The Substance
# 3                en          It Ends with Us
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  Soulmates Eric and Shelly are brutally murdere...    1403.514
# 1  Phillip and Suzanne are retired from the spy g...    1201.354
# ...

# %%
def get_best_fit(data, x, y):
    m = 0
    for count in range(100):
        m = m + 1
        b = 0

        # Calculate residuals (y = mx+b)
        res = 4291693874.339167
        for i in range(len(data)):
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
        print(res)
    return (m, b, res)

# %%
get_best_fit(df, "budget_sqrt", "revenue_sqrt")
# Out:
# 11311253092.008753
# 8583387748.678332
# 11550043907.347918
