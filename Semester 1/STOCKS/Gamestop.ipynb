# %%
import pandas as pd
import seaborn as sns

# %%
gme = pd.read_json('gme.json')

# %%
gme.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
gme.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5600 non-null   datetime64[ns]
#  1   Open       5600 non-null   float64
#  2   High       5600 non-null   float64
#  3   Low        5600 non-null   float64
#  4   Close      5600 non-null   float64
#  5   Adj Close  5600 non-null   float64
#  6   Volume     5600 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 306.4 KB

# %%
sns.lineplot(data=gme, x='Date', y='High')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
gme['High'].max()
# Out:
# 120.75

# %%
gme[gme['High']==120.75]
# Out:
#            Date   Open    High      Low      Close  Adj Close     Volume
# 4772 2021-01-28  66.25  120.75  28.0625  48.400002  48.400002  235263200

# %%
gme['High'].mean()
# Out:
# 9.531773437500012

# %%
gme['date_str'] = gme['Date'].astype(str)
gme[gme['date_str'].str.contains('2021-01-')]
# Out:
#            Date       Open        High        Low      Close  Adj Close  \
# 4755 2021-01-04   4.750000    4.775000   4.287500   4.312500   4.312500
# 4756 2021-01-05   4.337500    4.520000   4.307500   4.342500   4.342500
# 4757 2021-01-06   4.335000    4.745000   4.332500   4.590000   4.590000
# 4758 2021-01-07   4.617500    4.862500   4.505000   4.520000   4.520000
# 4759 2021-01-08   4.545000    4.575000   4.270000   4.422500   4.422500
# 4760 2021-01-11   4.852500    5.162500   4.752500   4.985000   4.985000
# 4761 2021-01-12   4.990000    5.100000   4.830000   4.987500   4.987500
# 4762 2021-01-13   5.105000    9.662500   5.007500   7.850000   7.850000
# 4763 2021-01-14   9.522500   10.765000   8.262500   9.977500   9.977500
# 4764 2021-01-15   9.622500   10.187500   8.502500   8.875000   8.875000
# 4765 2021-01-19  10.387500   11.380000   9.160000   9.840000   9.840000
# 4766 2021-01-20   9.342500   10.297500   9.015000   9.780000   9.780000
# ...

# %%
sns.scatterplot(data=gme, x='Low', y='Volume')
# Out:
# <AxesSubplot:xlabel='Low', ylabel='Volume'>

# %%
gme['High'].corr(gme['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27736\931514602.py in <module>
# ----> 1 gme['High'].corr(gme['Date'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2555
#    2556         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2557             return nanops.nancorr(
#    2558                 this.values, other.values, method=method, min_periods=min_periods
#    2559             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      86             if any(self.check(obj) for obj in obj_iter):
#      87                 f_name = f.__name__.replace("nan", "")
# ---> 88                 raise TypeError(
#      89                     f"reduction operation '{f_name}' not allowed for this dtype"
# ...

# %%
sns.scatterplot(data=gme, y='High', x='Date')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
###After 2020,

# %%
gme.tail
# Out:
# <bound method NDFrame.tail of            Date       Open       High        Low      Close  Adj Close  \
# 0    2002-02-13   2.406250   2.515000   2.381250   2.512500   1.691666
# 1    2002-02-14   2.543750   2.548750   2.481250   2.500000   1.683250
# 2    2002-02-15   2.500000   2.506250   2.462500   2.487500   1.674834
# 3    2002-02-19   2.475000   2.475000   2.343750   2.387500   1.607504
# 4    2002-02-20   2.400000   2.468750   2.381250   2.468750   1.662210
# ...         ...        ...        ...        ...        ...        ...
# 5595 2024-05-07  15.850000  17.290001  14.930000  16.309999  16.309999
# 5596 2024-05-08  16.049999  17.240000  15.330000  15.920000  15.920000
# 5597 2024-05-09  15.900000  18.510000  15.350000  18.010000  18.010000
# 5598 2024-05-10  17.930000  20.200001  16.879999  17.459999  17.459999
# 5599 2024-05-13  26.340000  38.200001  24.770000  30.450001  30.450001
#
#          Volume    date_str
# 0      76216000  2002-02-13
# ...

# %%
years = {}
for i in range(len(gme)):
    year = gme.loc[i]['Date'].year
    if year not in years.keys() and year != 2024:
        years[year]=1
    elif year in years.keys() and year!= 2024:
        years[year]+=1
sum(years.values())/len(years)
# Out:
# 250.36363636363637

# %% [markdown]
# # my api key
# 3TPIRAX0KU1Z7I0F

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=GME&interval=5min&apikey=3TPIRAX0KU1Z7I0F'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'GME', '3. Last Refreshed': '2024-09-26 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2024-09-26 19:55:00': {'1. open': '22.1790', '2. high': '22.2000', '3. low': '22.1600', '4. close': '22.1999', '5. volume': '1337'}, '2024-09-26 19:50:00': {'1. open': '22.1501', '2. high': '22.1880', '3. low': '22.1500', '4. close': '22.1500', '5. volume': '874'}, '2024-09-26 19:45:00': {'1. open': '22.1400', '2. high': '22.1800', '3. low': '22.1275', '4. close': '22.1599', '5. volume': '234'}, '2024-09-26 19:40:00': {'1. open': '22.1300', '2. high': '22.1895', '3. low': '22.1000', '4. close': '22.1200', '5. volume': '1982'}, '2024-09-26 19:35:00': {'1. open': '22.1300', '2. high': '22.1400', '3. low': '22.1000', '4. close': '22.1300', '5. volume': '603'}, '2024-09-26 19:30:00': {'1. open': '22.1500', '2. high': '22.1600', 
# ...

# %%
api=pd.DataFrame(data['Time Series (5min)'])
api.head()
# Out:
#           2024-09-26 19:55:00 2024-09-26 19:50:00 2024-09-26 19:45:00  \
# 1. open               22.1790             22.1501             22.1400
# 2. high               22.2000             22.1880             22.1800
# 3. low                22.1600             22.1500             22.1275
# 4. close              22.1999             22.1500             22.1599
# 5. volume                1337                 874                 234
#
#           2024-09-26 19:40:00 2024-09-26 19:35:00 2024-09-26 19:30:00  \
# 1. open               22.1300             22.1300             22.1500
# 2. high               22.1895             22.1400             22.1600
# 3. low                22.1000             22.1000             22.1100
# 4. close              22.1200             22.1300             22.1400
# 5. volume                1982                 603                 960
#
#           2024-09-26 19:25:00 2024-09-26 19:20:00 2024-09-26 19:15:00  \
# ...

# %%
# Out:
#                                                              Meta Data  \
# 1. Information       Intraday (5min) open, high, low, close prices ...
# 2. Symbol                                                          GME
# 3. Last Refreshed                                  2024-09-26 19:55:00
# 4. Interval                                                       5min
# 5. Output Size                                                 Compact
# ...                                                                ...
# 2024-09-26 12:00:00                                                NaN
# 2024-09-26 11:55:00                                                NaN
# 2024-09-26 11:50:00                                                NaN
# 2024-09-26 11:45:00                                                NaN
# 2024-09-26 11:40:00                                                NaN
#
#                                                     Time Series (5min)
# ...

# %%
GAMESTOPCOC = pd.concat([gme, api], axis=1, ignore_index=True)
GAMESTOPCOC
# Out:
#                  0        1        2        3        4         5    \
# 0         2002-02-13  2.40625  2.51500  2.38125  2.51250  1.691666
# 1         2002-02-14  2.54375  2.54875  2.48125  2.50000  1.683250
# 2         2002-02-15  2.50000  2.50625  2.46250  2.48750  1.674834
# 3         2002-02-19  2.47500  2.47500  2.34375  2.38750  1.607504
# 4         2002-02-20  2.40000  2.46875  2.38125  2.46875  1.662210
# ...              ...      ...      ...      ...      ...       ...
# 1. open          NaT      NaN      NaN      NaN      NaN       NaN
# 2. high          NaT      NaN      NaN      NaN      NaN       NaN
# 3. low           NaT      NaN      NaN      NaN      NaN       NaN
# 4. close         NaT      NaN      NaN      NaN      NaN       NaN
# 5. volume        NaT      NaN      NaN      NaN      NaN       NaN
#
#                   6           7        8        9    ...      98       99   \
# 0          76216000.0  2002-02-13      NaN      NaN  ...      NaN      NaN
# ...

# %%
swipe = True
if for you page
then
video
else replay
##this truly was our tiktok
#did we finally beat instagram reels?
#no that was youtube shorts
#those who know :evil trollface:
#hold up, his writing is this fire???
if gohan
cabba
#maintaining the agenda is our top priority -cabbage
#i better keep my ass in gt or im FINISHED
respect button ---------------------------------------------------------------------------------------------------------------->
#ei ei ei
#groomed
#nightcrwaler new carti crank that john
#i doom you 3000
#boom you looking for this
#schwarmachine
#i am steve
#tony im flying dead stick
those who know
# Out:
#   File "C:\Users\dngo6\AppData\Local\Temp\ipykernel_27736\1029811270.py", line 2
#     if for you page
#        ^
# SyntaxError: invalid syntax
