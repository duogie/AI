# %% [markdown]
# # Choose a Data Set
# Use data gathered from one of the following APIs:
# - [TV Series Endpoints from TMDB (you cannot use any of the Movie endpoints!)](https://developer.themoviedb.org/reference/tv-series-airing-today-list)
# - [Open Weather](https://openweathermap.org/api)
# - [NASA API](https://api.nasa.gov/)
# - [API Football](https://www.api-football.com/documentation-v3)
# - [RAWG Video Games](https://rawg.io/apidocs)
#
# **OR**
#
# Pick two or more datasets from one of the following folders:
# - [Olympic Games 2024](https://drive.google.com/drive/folders/1AqsNDn1HjdGBpj6CuxoGrog-Dg6Y_ecO?usp=sharing)
# - [Diabetes Indicators](https://drive.google.com/drive/folders/1lXwQOk3oMVZRIDB_DuD8IhMh7rjERsFH?usp=drive_link)
# - [Amazon Sales](https://drive.google.com/drive/folders/1VYUZ0vspKZQHgmbhe1qt-mjeeqVJJ58r?usp=drive_link)
# - [NBA](https://drive.google.com/drive/folders/1tBGqAJTpXRtmETAjSNyba_kRWGR4JKHt?usp=drive_link)
# - [Recipes](https://drive.google.com/drive/folders/18ybwQLoDTHF8EFfNtx9SxKco9Y4m9Z2I?usp=drive_link)

# %% [markdown]
# # My Question
# ### What is the relationship between the popularity of a TV show and its vote count? Do TV shows with greater popularity earn more votes?

# %% [markdown]
# # My Answer

# %%
import pandas as pd
import seaborn as sns
import requests
import numpy as np
url = "https://api.themoviedb.org/3/tv/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmM2MGFjMDRhM2FmMzQ4ZjUxNDdlMDQ3YzczMGI1OSIsIm5iZiI6MTcyNzk3MDMzMC43NDUzNzksInN1YiI6IjY2ZmViNzQ1ZmEzZTY5ZTBlZjdjOTE4OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Sb4BKNjHednSV65-8KJsMw2yL3hvL0NCwBsBL9l2DxU"
}

response = requests.get(url, headers=headers)
response = response.json()
tv = pd.DataFrame(response["results"])
tv
# Out:
#     adult                     backdrop_path                      genre_ids  \
# 0   False  /vgeDRVpSUa4Hvovg4C6dgm4dfUW.jpg                    [10766, 18]
# 1   False  /zUBbIcKnzw5MZqfc6Q8rlRdC6zX.jpg                 [10762, 10751]
# 2   False  /zSPvARNCFpZxmWjgJCsBu5PUlR9.jpg  [35, 18, 10751, 10762, 10759]
# 3   False  /4i3iJepkqqH5JJgTNLJdi8ke6ir.jpg                        [10766]
# 4   False  /mLcD1v4sfoa1juOsBat7Vik7wEe.jpg                        [10764]
# 5   False  /lmvsFQpAhx4k9dqKvOgb2B63MsC.jpg                 [10763, 10767]
# 6   False  /7ZBNbpkLhC2fS90j6onLS8qqfRX.jpg                             []
# 7   False  /jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg                        [10763]
# 8   False  /4ErOWmDGyGk0qCK1J8blAoj1a7a.jpg                           [18]
# 9   False  /2wNuLc0cEoPz6PZItftrZLHjG2k.jpg                    [18, 10751]
# 10  False                              None                       [18, 35]
# ...

# %%
tv['popularity'].corr(tvpop['vote_count'])
# Out:
# -0.0430695365113702

# %% [markdown]
# ## There is little correlation between popularity and vote count

# %%
X = tv['popularity'].values
y = tv['vote_count'].values
X = np.c_[np.ones(X.shape[0]), X]
balls = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
y_pred = X.dot(balls)
residuals = y - y_pred
SSR = np.sum(residuals**2)
import matplotlib.pyplot as plt
plt.scatter(y_pred, residuals)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted Values')
plt.show()

# %% [markdown]
# # The predicted values are not very accurate.

# %% [markdown]
# ***Describe analysis here.***

# %%
sns.regplot(data=tv, x='popularity', y='vote_count')
# Out:
# <AxesSubplot:xlabel='popularity', ylabel='vote_count'>

# %% [markdown]
# # The regression plot does not include a large amount of the actual data points in its prediction.

# %%
# Alternate between code for analysis and markdown descriptions of your analysis
# Add more code or markdown cells if needed to fully explain analysis

# %% [markdown]
# ***Describe analysis here.***

# %% [markdown]
# To answer my question, there is no relationship between a TV shows popularity and its vote count. While this could be for numerous reasons, my prediction is that its because most people who watch a show simply can't be bothered to put in their vote for the TV show. My other guess would be that votes and popularity are on two entirely different scales, and can't be accurately compared without changing the vote count to match popularity, or vice versa. The pearson correlation coefficient of these two statistics is -0.0430695365113702, meaning that there is essentially no correlation between vote count and popularity. Furthermore, the regression plot that I created doesn't include a large amount of the data within its prediction. And lastly, and maybe most evidently, on my residual plot, only 3 of my residuals actually line up with my predicted data, every other one is either over or under the prediction line. Thus, it should be clear that
