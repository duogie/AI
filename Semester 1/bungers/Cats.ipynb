# %%
import pandas as pd

# %%
pp = pd.read_csv('cats.csv')
print(pp.to_string())
# Out:
#      Unnamed: 0               Breed  Age (Years) Weight (kg)          Color  Gender     ID
# 0             0        Egyptian Mau           12           7          White    Male  181.0
# 1             1       Scottish Fold           17           8  Tortoiseshell    Male  907.0
# 2             2              Sphynx            9           9         Orange    Male  732.0
# 3             3            Oriental            6           7           Gray  Female  464.0
# 4             4            Savannah           14           7  Tortoiseshell  Female  451.0
# 5             5            Oriental            1           6          Black    Male  613.0
# 6             6            Balinese           14           4           Blue  Female  856.0
# 7             7            Savannah           11           9            Red  Female   98.0
# 8             8            Munchkin            6           8          Brown  Female  348.0
# ...

# %%
pp = pd.read_csv('cats.csv')
pp.loc[98]
# Out:
# Unnamed: 0             98
# Breed          Maine Coon
# Age (Years)             9
# Weight (kg)             5
# Color                Blue
# Gender             Female
# ID                  590.0
# Name: 98, dtype: object

# %%
import pandas as pd
data = {
    'Breed': ['Tabby'],
    'Age (Years)': [3],
    'Weight (kg)': [5],
    'Color': ['Orange'],
    'Gender': ['Male'],
    'ID': [420],
}
zuko = pd.DataFrame(data)

zuko.to_csv('cats.csv', mode='a', index=False, header=True)
pp=pd.read_csv('cats.csv')
pp.tail
# Out:
# <bound method NDFrame.tail of      Unnamed: 0          Breed  Age (Years) Weight (kg)          Color  \
# 0             0   Egyptian Mau           12           7          White
# 1             1  Scottish Fold           17           8  Tortoiseshell
# 2             2         Sphynx            9           9         Orange
# 3             3       Oriental            6           7           Gray
# 4             4       Savannah           14           7  Tortoiseshell
# ...         ...            ...          ...         ...            ...
# 1005      Tabby              3            5      Orange           Male
# 1006      Breed    Age (Years)  Weight (kg)       Color         Gender
# 1007      Tabby              3            5      Orange           Male
# 1008      Breed    Age (Years)  Weight (kg)       Color         Gender
# 1009      Tabby              3            5      Orange           Male
#
#       Gender     ID
# 0       Male  181.0
# 1       Male  907.0
# 2       Male  732.0
# ...

# %%
pp['Weight (lbs)'] = pp['Weight (kg)'] * 2.205
pp.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...
