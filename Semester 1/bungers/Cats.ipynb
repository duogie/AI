# %%
import pandas as pd
pp = pd.read_csv('cats.csv')
print(pp.to_string())
# Out:
#      Unnamed: 0               Breed  Age (Years)  Weight (kg)          Color  Gender   ID
# 0             0        Egyptian Mau           12            7          White    Male  181
# 1             1       Scottish Fold           17            8  Tortoiseshell    Male  907
# 2             2              Sphynx            9            9         Orange    Male  732
# 3             3            Oriental            6            7           Gray  Female  464
# 4             4            Savannah           14            7  Tortoiseshell  Female  451
# 5             5            Oriental            1            6          Black    Male  613
# 6             6            Balinese           14            4           Blue  Female  856
# 7             7            Savannah           11            9            Red  Female   98
# 8             8            Munchkin            6            8          Brown  Female  348
# ...

# %%
pp.column

# %%
pp.drop(['Unnamed: 0'], inplace=true, axis=0)
pp.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6244\3671366849.py in <module>
# ----> 1 pp.drop(['Unnamed: 0'], inplace=true, axis=0)
#       2 pp.head()
#
# NameError: name 'true' is not defined
