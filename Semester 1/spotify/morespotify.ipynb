# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("spotify_songs.csv")
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
sns.histplot(data=df, x="track_popularity", bins=50)
# Out:
# <AxesSubplot:xlabel='track_popularity', ylabel='Count'>

# %% [markdown]
# # track popularity distribution
# Somewhat of a bell curve
# Most amount of songs at 0 track popularity

# %%
df.loc[df['track_name']=="Dance Monkey"]
# Out:
#                      track_id    track_name track_artist  track_popularity  \
# 623    3g1MMelMBxLjtKwcIVFe0N  Dance Monkey      Skylike                63
# 922    5ZULALImTm80tzUbYQYM9d  Dance Monkey  Tones and I                92
# 1298   1rgnBhdG2JDFTbYkYRZAku  Dance Monkey  Tones and I                79
# 1349   421leiR6jKlH5KDdwLYrOs  Dance Monkey  Tones and I                43
# 1551   2XU0oxnq2qxCpomAAuJY8K  Dance Monkey  Tones and I               100
# 4699   421leiR6jKlH5KDdwLYrOs  Dance Monkey  Tones and I                43
# 10348  1LCG7BBh96DUUV6MuQhFad  Dance Monkey       Coopex                57
# 17088  0y3elN0Dm4b0bYQEQgTatE  Dance Monkey  Yann Muller                53
# 18312  5ZULALImTm80tzUbYQYM9d  Dance Monkey  Tones and I                92
# 19262  421leiR6jKlH5KDdwLYrOs  Dance Monkey  Tones and I                43
# 19720  5ZULALImTm80tzUbYQYM9d  Dance Monkey  Tones and I                92
# ...

# %% [markdown]
# # It is very impressive, there are very few songs that received 100 popularity scores purely based on the histogram. Even Dance Monkey itself only received a score of 100 twice out of the 12 versions released by Tones and I.
# ## Are there any songs with a tempo outside of the standard deviation of tempo?

# %%
sns.histplot(data=df, x="tempo", bins=50)
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='Count'>

# %%
sdtempo = df['tempo'].std()
sdtempo
# Out:
# 26.90362417188013

# %%
mtempo = df['tempo'].mean()
mtempo
# Out:
# 120.88113154448297

# %% [markdown]
# # Yes, there are numerous songs with tempo outside of the standard deviation of tempo
